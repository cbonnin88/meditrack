# %% [markdown]
# <a href="https://colab.research.google.com/github/cbonnin88/meditrack/blob/main/EDA_and_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import polars as pl
import plotly.express as px
import gdown as gd

# %%
url_events = 'https://drive.google.com/uc?id=1DT00olR4KK_zMYXtMEm4q1LViasRc1Gn'
url_subs = 'https://drive.google.com/uc?id=1qNJJ8e8p-VbZ0HkfceOhqxoHsTFGEXGl'
url_users = 'https://drive.google.com/uc?id=1gLZgyIa17KoZsMrwP0-rg6cEFeAoD44O'

# %%
gd.download(url_subs,'meditrack_subs_clean.csv',quiet=True)
# Out:
# 'meditrack_subs_clean.csv'

# %%
gd.download(url_events,'meditrack_events_clean.csv',quiet=True)
# Out:
# 'meditrack_events_clean.csv'

# %%
gd.download(url_users,'meditrack_users_clean.csv',quiet=True)
# Out:
# 'meditrack_users_clean.csv'

# %%
df_users = pl.read_csv('meditrack_users_clean.csv')
df_events = pl.read_csv('meditrack_events_clean.csv')
df_subs = pl.read_csv('meditrack_subs_clean.csv')

# %% [markdown]
# # **Joining Users and Subscriptions for analysis**

# %%
# Using a left join
df_combined = df_users.join(df_subs, on='user_id',how='left')

# %% [markdown]
# # **Convert Churned to a string label for better plotting legibility**

# %%
df_combined = df_combined.with_columns(
    pl.when(pl.col('churned')== 1).then(pl.lit('Churned'))
    .otherwise(pl.lit('Active'))
    .alias('status')
)

# %%
print(f'Data Loaded. Combined Rows: {df_combined.height}')
# Out:
# Data Loaded. Combined Rows: 970

# %% [markdown]
# # **Churn by Age**
#
# - **Business Question:** Is our app failing with a specific age group? Are older users dropping off because the font size is too small?

# %%
fig_churn_by_age = px.histogram(
    df_combined.to_pandas(),
    x='age',
    color='status',
    barmode='overlay',
    title='User Distribution by Age= Active vs Churned',
    labels={'age':'User Age','count':'Number of Users'},
    opacity=0.7,
    color_discrete_map={'Active':'blue','Churned':'red'}
)

fig_churn_by_age.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="94d28524-82e5-4106-9fab-adba0f72775a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94d28524-82e5-4106-9fab-adba0f72775a")) {                    Plotly.newPlot(                        "94d28524-82e5-4106-9fab-adba0f72775a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"status=Active\u003cbr\u003eUser Age=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Active","marker":{"color":"blue","opacity":0.7,"pattern":{"shape":""}},"name":"Active","offsetgroup":"Active","orientation":"v","showlegend":true,"x":[58,32,52,23,32,50,80,27,43,43,36,34,20,45,77,32,78,70,32,46,48,59,66,57,54,45,49,36,38,30,80,62,33,53,45,25,78,53,57,46,38,28,24,35,30,27,25,60,39,19,79,60,40,22,67,20,59,50,20,39,79,78,44,77,68,62,31,34,56,20,68,67,51,72,48,33,26,50,63,36,33,74,62,57,66,55,52,65,33,43,47,51,33,20,45,49,24,37,24,43,53,20,25,42,77,80,67,51,67,29,29,27,44,24,22,21,19,63,31,54,54,20,80,40,36,55,61,30,47,68,64,56,68,76,50,71,76,49,56,25,29,25,28,76,59,50,19,78,41,65,24,70,57,55,67,57,55,43,58,30,29,64,71,64,18,51,78,68,60,51,37,24,53,46,20
# %% [markdown]
# Daily Active Users (Time Series)
#
# - **Business Question:** Are we growing? Do we have usage spikes on weekends or weekdays?

# %%
# Aggregate Events by Date
daily_activity = (
    df_events
    .group_by('event_timestamp')
    .len()
    .rename({'len':'event_count'})
    .sort('event_timestamp')
)

display(daily_activity)
# Out:
# shape: (366, 2)
# ┌─────────────────┬─────────────┐
# │ event_timestamp ┆ event_count │
# │ ---             ┆ ---         │
# │ str             ┆ u32         │
# ╞═════════════════╪═════════════╡
# │ 2024-11-27      ┆ 16          │
# │ 2024-11-28      ┆ 21          │
# │ 2024-11-29      ┆ 17          │
# │ 2024-11-30      ┆ 22          │
# │ 2024-12-01      ┆ 14          │
# │ …               ┆ …           │
# │ 2025-11-23      ┆ 17          │
# │ 2025-11-24      ┆ 20          │
# │ 2025-11-25      ┆ 22          │
# │ 2025-11-26      ┆ 16          │
# │ 2025-11-27      ┆ 16          │
# └─────────────────┴─────────────┘

# %%
fig_daily_active_users = px.line(
    daily_activity.to_pandas(),
    x='event_timestamp',
    y='event_count',
    title='Daily App Events (Growth Metric)',
    markers=True,
    color_discrete_sequence=['#77DD77']
)

fig_daily_active_users.update_layout(xaxis_title='Date',yaxis_title='Total Events')
fig_daily_active_users.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b8534caa-2beb-401b-8392-d680e698607e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8534caa-2beb-401b-8392-d680e698607e")) {                    Plotly.newPlot(                        "b8534caa-2beb-401b-8392-d680e698607e",                        [{"hovertemplate":"event_timestamp=%{x}\u003cbr\u003eevent_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#77DD77","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2024-11-27","2024-11-28","2024-11-29","2024-11-30","2024-12-01","2024-12-02","2024-12-03","2024-12-04","2024-12-05","2024-12-06","2024-12-07","2024-12-08","2024-12-09","2024-12-10","2024-12-11","2024-12-12","2024-12-13","2024-12-14","2024-12-15","2024-12-16","2024-12-17","2024-12-18","2024-12-19","2024-12-20","2024-12-21","2024-12-22","2024-12-23","2024-12-24","2024-12-25","2024-12-26","2024-12-27","2024-12-28","2024-12-29","2024-12-30","2024-12-31","2025-01-01","2025-01-02","2025-01-03","2025-01-04","2025-01-05","2025-01-06","2025-01-07","2025-01-08","2025-01-09","2025-01-10","2025-01-11","2025-01-12","2025-01-13","2025-01-14","2025-01-15","2025-01-16","2025-01-17","2025-01-18","2025-01-19","2025-01-20","2025-01-21","2025-01-22","2025-01-23","2025-01-24","2025-01-25","2025-01-26","2025-01-27","2025-01-28","2025-01-29","2025-01-30","2025-01-31","2025-02-01","2025-02-02","2025-02-03","2025-02-04","2025-02-05","2025-02-06","2025-02-07","2025-02-08","2025-02-09","2025-02-10","2025-02-11","2025-02-12","2025-02-13","2025-02-14","2025-02-15","2025-02-16","2025-02-17","2025-02-18","2025-02-19","2025-02-20","2025-02-21","2025-02-22","2025-02-23","2025-02-24","2025-02-25","2025-02-26","2025-02-27","2025-02-28","2025-03-01","2025-03-02","2025-03-03","2025-03-04","2025-03-05","2025-03-06","2025-03-07","2025-03-08","2025-03-09","2025-03-10","2025-03-11","2025-03-12","2025-03-13","2025-03-14","2025-03-15","2025-03-16","2025-03-17","2025-03-18","2025-03-19","2025-03-20","2025-03-21","2025-03-22","2025-03-23","2025-03-24","2025-03-25","2025-03-26","2025-03-27","2025-03-28","2025-03-29","2025-03-30","2025-03-31","2025-04-01","2025-04-02","2025-04-03","2025-04-04","2025-04-05","2025-04-06","2025-04-07","2025-04-08","2025-04-09","2025-04-10","2025-04-11","2025-04-12","2025-04-13","2025-04-14","2025-04-15","2025-04-16","2025-04-17","2025-04-18","2025-04-19","2025-04-20","2025-04-21","2025-04-22","2025-04-23","2025-04-24","2025-04-25","2025-04-26","2025-04-27","2025-04-28","2025-04-29","2025-04-30","2025-05-01","2025-05-02","2025-05-03","2025-05-04","2025-05-05","2025-05-06","2025-05-07","2025-05-08","2025-05-09","2025-05-10","2025-05-11","2025-05-12","2025-05-13","2025-05-14","2025-05-15","2025-05-16","2025-05-17","2025-05-18","2025-05-19","2025-05-20","2025-05-21","2025-05-22","2025-05-23","2025-05-24","2025-05-25","2025-05-26","2025-05-27","2025-05-28","2025-05-29","2025-05-30","2025-05-31","2025-06-01","2025-06-02","2025-06-03","2025-06-04","2025-06-05","2025-06-06","2025-06-07","2025-06-08","2025-06-09","2025-06-10","2025-06-11","2025-06-12","2025-06-13","2025-06-14","2025-06-15","2025-06-16","2025-06-17","2025-06-18","2025-06-19","2025-06-20","2025-06-21","2025-06-22","2025-06-23","2025-06-24","2025-06-25","2025-06-26","2025-06-27","2025-06-28","2025-06-29","2025-06-30","2025-07-01","2025-07-02","2025-07-03","2025-07-04","2025-07-05","2025-07-06","2025-07-07","2025-07-08","2025-07-09","2025-07-10","2025-07-11","2025-07-12","2025-07-13","2025-07-14","2025-07-15","2025-07-16","2025-07-17","2025-07-18","2025-07-19","2025-07-20","2025-07-21","2025-07-22","2025-07-23","2025-07-24","2025-07-25","2025-07-26","2025-07-27","202 ...

# %% [markdown]
# # **Revenue Box Plot by Channel**
#
# - **Business Question:** Which marketing channel brings in the "Whales" (users who pay higher fees)?

# %%
fig_revenue = px.box(
    df_combined.to_pandas(),
    x='acquisition_channel',
    y='monthly_fee',
    color='acquisition_channel',
    title='Revenue Distribution by Acquisition Channel',
    points='all'
)

fig_revenue.update_layout(xaxis_title='Acquisition Channel',yaxis_title='Monthly Fee')

fig_revenue.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d5bd5b6d-9ab0-455a-b2bb-1d82123206dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5bd5b6d-9ab0-455a-b2bb-1d82123206dc")) {                    Plotly.newPlot(                        "d5bd5b6d-9ab0-455a-b2bb-1d82123206dc",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"acquisition_channel=%{x}\u003cbr\u003emonthly_fee=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Google","marker":{"color":"#636efa"},"name":"Google","notched":false,"offsetgroup":"Google","orientation":"v","showlegend":true,"x":["Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google","Google"],"x0":" ","xaxis":"x","y":[10.95,20.95,10.95,10.95,10.95,20.95,20.95,20.95,10.95,20.95,10.95,10.95,20.95,10.95,20.95,20.95,20.95,10.95,10.95,20.95,20.95,20.95,10.95,10.95,20.95,20.95,20.95,10.95,20.95,20.95,20.95,10.95,10.95,10.95,20.95,10.95,10.95,20.95,20.95,10.95,20.95,10.95,10.95,10.95,20.95,10.95,10.95,20.95,10.95,20.95,10.95,10.95,20.95,20.95,10.95,10.95,20.95,20.95,20.95,10.95,10.95,10.95,10.95,20.95,20.95,20.95,20.95,10.95,20.95,10.95,20.95,20.95,10.95,20.95,10.95,20.95,10.95,10.95,10.95,20.95,10.95,10.95,10.95,10.95,10.95,10.95,10.95,10.95,10.95,10.95,10.95,20.95,10.95,20.95,20.95,20.95,20.95,10.95,10.95,10.95,10.95,10.95,10.95,20.95,20.95,10.95,10.95,10.95,20.95,10.95,10.95,10.95,20.95,20.95,10.95,20.95,20.95,10.95,10.95,20.95,10.95,20.95,20.95,10.95,10.95,20.95,10.95,20.95,20.95,10.95,20.95,20.95,10.95,10.95,20.95,20.95,20.95,10.95,10.95,10.95,10.95,10.95,10.95,10.95,20.95,10.95,20.95,20.95,10.95,20.95,20.95,10.95,10.95,20.95,20. ...

# %% [markdown]
# # **Activity Heatmap (Day vs Hour)**
#
# - Business Question: When are our users most active? Do we need to scale up servers on Monday mornings or Friday nights?

# %%
# Extracting Day and Hour
heatmap_data = (
    df_events
    .with_columns([
        pl.col('event_timestamp').str.to_datetime().dt.weekday().alias('weekday_num'),
        pl.col('event_timestamp').str.to_datetime().dt.hour().alias('hour_of_day')
    ])
    .group_by(['weekday_num','hour_of_day'])
    .len()
    .sort(['weekday_num','hour_of_day'])
)

display(heatmap_data)
# Out:
# shape: (7, 3)
# ┌─────────────┬─────────────┬─────┐
# │ weekday_num ┆ hour_of_day ┆ len │
# │ ---         ┆ ---         ┆ --- │
# │ i8          ┆ i8          ┆ u32 │
# ╞═════════════╪═════════════╪═════╡
# │ 1           ┆ 0           ┆ 935 │
# │ 2           ┆ 0           ┆ 916 │
# │ 3           ┆ 0           ┆ 872 │
# │ 4           ┆ 0           ┆ 925 │
# │ 5           ┆ 0           ┆ 888 │
# │ 6           ┆ 0           ┆ 923 │
# │ 7           ┆ 0           ┆ 923 │
# └─────────────┴─────────────┴─────┘

# %%
# Pivoting for Heatmap format (Matrix) using pandas
heatmap_matrix = heatmap_data.to_pandas().pivot(index='weekday_num',columns='hour_of_day',values='len').fillna(0)

# %%
fig_activity = px.imshow(
    heatmap_matrix,
    labels=dict(x='Hour of Day',y='Day of the Week (1=Mon, 7=Sun)', color='Event Volume'),
    x=heatmap_matrix.columns,
    y=heatmap_matrix.index,
    color_continuous_scale='BuPu',
    title='Heatmap: User Activity by Time & Day'
)

fig_activity.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1ca97647-8a65-4403-9424-0197ed4ef73a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ca97647-8a65-4403-9424-0197ed4ef73a")) {                    Plotly.newPlot(                        "1ca97647-8a65-4403-9424-0197ed4ef73a",                        [{"coloraxis":"coloraxis","name":"0","x":[0],"y":[1,2,3,4,5,6,7],"z":[[935],[916],[872],[925],[888],[923],[923]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Hour of Day: %{x}\u003cbr\u003eDay of the Week (1=Mon, 7=Sun): %{y}\u003cbr\u003eEvent Volume: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"color ...

# %% [markdown]
# # **Engagement vs. Age Scatter Plot**
#
# - Business Question: Do younger people use the app more intensely than older people? Is there a correlation between Age and Total Events?

# %%
# Calculate Events per User
user_activity = df_events.group_by('user_id').len().rename({'len': 'total_events'})

display(user_activity)
# Out:
# shape: (970, 2)
# ┌─────────────────────────────────┬──────────────┐
# │ user_id                         ┆ total_events │
# │ ---                             ┆ ---          │
# │ str                             ┆ u32          │
# ╞═════════════════════════════════╪══════════════╡
# │ 86052bef-c382-4725-a1c6-3384ee… ┆ 4            │
# │ b64a46f5-eb6d-435f-a950-94bbf3… ┆ 5            │
# │ 13d94ad0-d809-4e6d-b41a-d2c25c… ┆ 6            │
# │ 25dccca2-054e-4210-a3c9-f400ba… ┆ 7            │
# │ 1034794e-db2b-41be-ba73-5eb299… ┆ 1            │
# │ …                               ┆ …            │
# │ 77dd362b-4a6b-436b-957f-108b86… ┆ 6            │
# │ 1c5d9fe9-0b07-4a68-88f2-17a3e2… ┆ 7            │
# │ 159d880c-76a5-425c-8f90-bfaab4… ┆ 5            │
# │ 9c3a1e0b-b5f3-48aa-9c6d-afff59… ┆ 9            │
# │ e8180064-3e44-4305-ab55-920d81… ┆ 9            │
# └─────────────────────────────────┴──────────────┘

# %%
# Joining with User Demographics
scatter_data = (
    df_users
    .join(user_activity, on='user_id', how='inner')
    .filter(pl.col('age').is_not_null())
)

display(scatter_data)
# Out:
# shape: (970, 7)
# ┌─────────────────┬─────────────┬─────┬─────────────────┬─────────┬─────────────────┬──────────────┐
# │ user_id         ┆ signup_date ┆ age ┆ email           ┆ country ┆ acquisition_cha ┆ total_events │
# │ ---             ┆ ---         ┆ --- ┆ ---             ┆ ---     ┆ nnel            ┆ ---          │
# │ str             ┆ str         ┆ i64 ┆ str             ┆ str     ┆ ---             ┆ u32          │
# │                 ┆             ┆     ┆                 ┆         ┆ str             ┆              │
# ╞═════════════════╪═════════════╪═════╪═════════════════╪═════════╪═════════════════╪══════════════╡
# │ 86052bef-c382-4 ┆ 2025-10-23  ┆ 38  ┆ charlesfranco@e ┆ Denmark ┆ Referral        ┆ 4            │
# │ 725-a1c6-3384ee ┆             ┆     ┆ xample.net      ┆         ┆                 ┆              │
# │ …               ┆             ┆     ┆                 ┆         ┆                 ┆              │
# │ b64a46f5-eb6d-4 ┆ 2025-06-01  ┆ 80  ┆ websterkelly@ex ┆ France  ┆ Google          ┆ 5            │
# │ 35f-a950-94bbf3 ┆             ┆     ┆ ample.org       ┆         ┆                 ┆              │
# │ …               ┆             ┆     ┆                 ┆         ┆                 ┆              │
# │ 13d94ad0-d809-4 ┆ 2025-06-23  ┆ 77  ┆ mjohnson@exampl ┆ Denmark ┆ Referral        ┆ 6            │
# │ e6d-b41a-d2c25c ┆             ┆     ┆ e.org           ┆         ┆                 ┆              │
# │ …               ┆             ┆     ┆                 ┆         ┆                 ┆              │
# │ 25dccca2-054e-4 ┆ 2025-11-20  ┆ 29  ┆ donnathomas@exa ┆ Ireland ┆ Google          ┆ 7            │
# │ 210-a3c9-f400ba ┆             ┆     ┆ mple.com        ┆         ┆                 ┆              │
# │ …               ┆             ┆     ┆                 ┆         ┆                 ┆              │
# │ 1034794e-db2b-4 ┆ 2025-06-08  ┆ 32  ┆ jeanette06@exam ┆ Ireland ┆ Organic         ┆ 1            │
# │ 1be-ba73-5eb299 ┆             ┆     ┆ ple.com         ┆         ┆                 ┆              │
# │ …               ┆             ┆     ┆                 ┆         ┆                 ┆              │
# │ …               ┆ …           ┆ …   ┆ …               ┆ …       ┆ …               ┆ …            │
# │ 77dd362b-4a6b-4 ┆ 2025-05-06  ┆ 65  ┆ ievans@example. ┆ Ireland ┆ Google          ┆ 6            │
# │ 36b-957f-108b86 ┆             ┆     ┆ net             ┆         ┆                 ┆              │
# │ …               ┆             ┆     ┆                 ┆         ┆                 ┆              │
# │ 1c5d9fe9-0b07-4 ┆ 2024-12-14  ┆ 47  ┆ charles59@examp ┆ Denmark ┆ Google          ┆ 7            │
# │ a68-88f2-17a3e2 ┆             ┆     ┆ le.com          ┆         ┆                 ┆              │
# │ …               ┆             ┆     ┆                 ┆         ┆                 ┆              │
# │ 159d880c-76a5-4 ┆ 2025-02-06  ┆ 48  ┆ unknown@meditra ┆ France  ┆ Referral        ┆ 5            │
# │ 25c-8f90-bfaab4 ┆             ┆     ┆ ck.coom         ┆         ┆                 ┆              │
# │ …               ┆             ┆     ┆                 ┆         ┆                 ┆              │
# │ 9c3a1e0b-b5f3-4 ┆ 2025-07-16  ┆ 78  ┆ christinaglover ┆ Ireland ┆ Organic         ┆ 9            │
# │ 8aa-9c6d-afff59 ┆             ┆     ┆ @example.org    ┆         ┆                 ┆              │
# │ …               ┆             ┆     ┆                 ┆         ┆                 ┆              │
# │ e8180064-3e44-4 ┆ 2025-11-01  ┆ 60  ┆ unknown@meditra ┆ Ireland ┆ Referral        ┆ 9            │
# │ 305-ab55-920d81 ┆             ┆     ┆ ck.coom         ┆         ┆                 ┆              │
# │ …               ┆             ┆     ┆                 ┆         ┆                 ┆              │
# └─────────────────┴─────────────┴─────┴─────────────────┴─────────┴─────────────────┴──────────────┘

# %%
fig_engagement = px.scatter(
    scatter_data.to_pandas(),
    x='age',
    y='total_events',
    color='acquisition_channel',
    title='Correlation: User Age vs. App Usage Intensity',
    opacity=0.6,
    trendline='ols'
)

fig_engagement.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="96783196-a027-41fd-894c-9fedd42c4e23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96783196-a027-41fd-894c-9fedd42c4e23")) {                    Plotly.newPlot(                        "96783196-a027-41fd-894c-9fedd42c4e23",                        [{"hovertemplate":"acquisition_channel=Referral\u003cbr\u003eage=%{x}\u003cbr\u003etotal_events=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Referral","marker":{"color":"#636efa","opacity":0.6,"symbol":"circle"},"mode":"markers","name":
80,80],"xaxis":"x","y":[6.092319780698975,6.092319780698975,6.092319780698975,6.092319780698975,6.092319780698975,6.113368183658373,6.113368183658373,6.113368183658373,6.113368183658373,6.113368183658373,6.113368183658373,6.113368183658373,6.123892385138072,6.134416586617772,6.134416586617772,6.144940788097471,6.144940788097471,6.144940788097471,6.144940788097471,6.144940788097471,6.144940788097471,6.155464989577171,6.155464989577171,6.155464989577171,6.155464989577171,6.16598919105687,6.16598919105687,6.16598919105687,6.16598919105687,6.16598919105687,6.176513392536569,6.176513392536569,6. ...

# %% [markdown]
# # **Churn Composition**
#
# - Business Question: Of the people who Churned, what platforms were they on? Did Android users churn more than iOS users?

# %%
# Finding the last platform used for every user
last_platform= (
    df_events
    .sort('event_timestamp',descending=True)
    .unique(subset=['user_id'], keep='first')
    .select(['user_id','platform'])
)

display(last_platform)
# Out:
# shape: (970, 2)
# ┌─────────────────────────────────┬──────────┐
# │ user_id                         ┆ platform │
# │ ---                             ┆ ---      │
# │ str                             ┆ str      │
# ╞═════════════════════════════════╪══════════╡
# │ 7ab417d6-2975-4ef7-9d3f-904a5c… ┆ Android  │
# │ 03e7dd21-1d4d-46d6-860d-113d28… ┆ Android  │
# │ 1aa6f7cb-90c7-46ac-a3bf-e40338… ┆ Android  │
# │ fef72410-5528-4c45-a37a-a99961… ┆ Android  │
# │ 88ccddbc-6f0d-4229-9b38-7c72ac… ┆ Web      │
# │ …                               ┆ …        │
# │ 0b44f907-6d59-4e12-9ac7-b94d1c… ┆ Web      │
# │ 935b67b4-2fbd-4d23-a516-8cda99… ┆ iOS      │
# │ 21c4f6d5-95ea-478b-8ce3-edb778… ┆ iOS      │
# │ 2d1b143e-1da6-436d-acc3-f8aaa9… ┆ iOS      │
# │ b5786277-761c-4a2b-9263-f8e03c… ┆ iOS      │
# └─────────────────────────────────┴──────────┘

# %%
# Joining with Subscription Status
churn_platform_data = (
    df_subs
    .join(last_platform, on='user_id')
    .filter(pl.col('churned')==1)
    .group_by('platform')
    .len()
)

display(churn_platform_data)
# Out:
# shape: (3, 2)
# ┌──────────┬─────┐
# │ platform ┆ len │
# │ ---      ┆ --- │
# │ str      ┆ u32 │
# ╞══════════╪═════╡
# │ iOS      ┆ 159 │
# │ Web      ┆ 177 │
# │ Android  ┆ 175 │
# └──────────┴─────┘

# %%
fig_churn = px.pie(
    churn_platform_data.to_pandas(),
    values='len',
    names='platform',
    title='Churn Breakdown by Platform',
    hole=0.4,
    color_discrete_sequence=["#FFB3BA", "#BAFFC9", "#BAE1FF"]
)

fig_churn.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4d9b29f9-c6fd-4a82-9b4a-27ed16ce7675" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d9b29f9-c6fd-4a82-9b4a-27ed16ce7675")) {                    Plotly.newPlot(                        "4d9b29f9-c6fd-4a82-9b4a-27ed16ce7675",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"platform=%{label}\u003cbr\u003elen=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["iOS","Web","Android"],"legendgroup":"","name":"","showlegend":true,"values":[159,177,175],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histo ...
