# %% [markdown]
# <a href="https://colab.research.google.com/github/cbonnin88/meditrack/blob/main/ml_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import polars as pl
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import plotly.express as px
import gdown as gd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import random

# %%
url_users ='https://drive.google.com/uc?id=1gLZgyIa17KoZsMrwP0-rg6cEFeAoD44O'
url_events = 'https://drive.google.com/uc?id=1DT00olR4KK_zMYXtMEm4q1LViasRc1Gn'
url_subs = 'https://drive.google.com/uc?id=1qNJJ8e8p-VbZ0HkfceOhqxoHsTFGEXGl'

# %%
gd.download(url_subs,'meditrack_subs_clean.csv',quiet=True)
# Out:
# 'meditrack_subs_clean.csv'

# %%
gd.download(url_events,'meditrack_events_clean.csv',quiet=True)
# Out:
# 'meditrack_events_clean.csv'

# %%
gd.download(url_users,'meditrack_users_clean.csv',quiet=True)
# Out:
# 'meditrack_users_clean.csv'

# %%
df_users = pl.read_csv('meditrack_users_clean.csv')
df_events = pl.read_csv('meditrack_events_clean.csv')
df_subs = pl.read_csv('meditrack_subs_clean.csv')

# %%
df_users.head()
# Out:
# shape: (5, 6)
# ┌───────────────────────┬─────────────┬─────┬──────────────────────┬─────────┬─────────────────────┐
# │ user_id               ┆ signup_date ┆ age ┆ email                ┆ country ┆ acquisition_channel │
# │ ---                   ┆ ---         ┆ --- ┆ ---                  ┆ ---     ┆ ---                 │
# │ str                   ┆ str         ┆ i64 ┆ str                  ┆ str     ┆ str                 │
# ╞═══════════════════════╪═════════════╪═════╪══════════════════════╪═════════╪═════════════════════╡
# │ bdd640fb-0667-4ad1-9c ┆ 2025-03-07  ┆ 58  ┆ unknown@meditrack.co ┆ Denmark ┆ Google              │
# │ 80-317fa3…            ┆             ┆     ┆ om                   ┆         ┆                     │
# │ 1a3d1fa7-bc89-40a9-a3 ┆ 2025-08-01  ┆ 32  ┆ garzaanthony@example ┆ Ireland ┆ Instagram           │
# │ b8-c1e939…            ┆             ┆     ┆ .org                 ┆         ┆                     │
# │ a28defe3-9bf0-4273-92 ┆ 2025-01-28  ┆ 52  ┆ frankgray@example.ne ┆ Denmark ┆ Instagram           │
# │ 47-6f57a5…            ┆             ┆     ┆ t                    ┆         ┆                     │
# │ 3602f8ac-10f1-4c81-84 ┆ 2025-10-27  ┆ 54  ┆ jason76@example.net  ┆ France  ┆ Google              │
# │ 8a-aa9e66…            ┆             ┆     ┆                      ┆         ┆                     │
# │ 81f631d4-a392-41a7-97 ┆ 2025-07-07  ┆ 70  ┆ nathanielmartin@exam ┆ Denmark ┆ Referral            │
# │ 77-a4774c…            ┆             ┆     ┆ ple.net              ┆         ┆                     │
# └───────────────────────┴─────────────┴─────┴──────────────────────┴─────────┴─────────────────────┘

# %%
df_events.head()
# Out:
# shape: (5, 5)
# ┌────────────────────────────┬───────────────────────────┬────────────┬─────────────────┬──────────┐
# │ event_id                   ┆ user_id                   ┆ event_name ┆ event_timestamp ┆ platform │
# │ ---                        ┆ ---                       ┆ ---        ┆ ---             ┆ ---      │
# │ str                        ┆ str                       ┆ str        ┆ str             ┆ str      │
# ╞════════════════════════════╪═══════════════════════════╪════════════╪═════════════════╪══════════╡
# │ 3d7d9e1e-c7e1-46e3-bf71-d4 ┆ 233ffc82-92ec-49af-93ae-c ┆ app_open   ┆ 2025-09-30      ┆ iOS      │
# │ 015f…                      ┆ 376c3…                    ┆            ┆                 ┆          │
# │ 9f130820-0f3b-45f9-9345-c5 ┆ 8aa9d39a-726f-46fd-8ec9-8 ┆ book_apt   ┆ 2025-05-22      ┆ Android  │
# │ 26a4…                      ┆ bf100…                    ┆            ┆                 ┆          │
# │ baedb7ab-965e-45d5-8735-93 ┆ ef32f72a-a4b5-4723-82fb-2 ┆ app_open   ┆ 2025-08-23      ┆ Android  │
# │ d177…                      ┆ 8690d…                    ┆            ┆                 ┆          │
# │ b1a33f6d-e3db-4202-9516-f8 ┆ 4c6694ab-57b5-4de2-b1ae-8 ┆ video_call ┆ 2025-07-21      ┆ Web      │
# │ 1c43…                      ┆ 4bec7…                    ┆            ┆                 ┆          │
# │ 19664504-6e7e-4978-869d-7b ┆ b4adaf89-0ff1-4a9f-ba37-0 ┆ book_apt   ┆ 2025-08-05      ┆ Android  │
# │ 0161…                      ┆ 623bc…                    ┆            ┆                 ┆          │
# └────────────────────────────┴───────────────────────────┴────────────┴─────────────────┴──────────┘

# %%
df_subs.head()
# Out:
# shape: (5, 3)
# ┌─────────────────────────────────┬─────────────┬─────────┐
# │ user_id                         ┆ monthly_fee ┆ churned │
# │ ---                             ┆ ---         ┆ ---     │
# │ str                             ┆ f64         ┆ i64     │
# ╞═════════════════════════════════╪═════════════╪═════════╡
# │ bdd640fb-0667-4ad1-9c80-317fa3… ┆ 10.95       ┆ 0       │
# │ 1a3d1fa7-bc89-40a9-a3b8-c1e939… ┆ 10.95       ┆ 0       │
# │ a28defe3-9bf0-4273-9247-6f57a5… ┆ 20.95       ┆ 0       │
# │ 3602f8ac-10f1-4c81-848a-aa9e66… ┆ 20.95       ┆ 1       │
# │ 81f631d4-a392-41a7-9777-a4774c… ┆ 10.95       ┆ 1       │
# └─────────────────────────────────┴─────────────┴─────────┘

# %% [markdown]
# # **Churn Prediction Model**

# %%
# Feature A: Activity Level ( How many events did they do ?)
event_counts = df_events.group_by('user_id').len().rename({'len':'total_events'})

# %%
# Feature B: Last Platform Used (Did they struggle on Web ?)
last_platform = (
    df_events.sort('event_timestamp', descending=True)
    .unique(subset=['user_id'], keep='first')
    .select(['user_id','platform'])
)

# %%
# Join everything into one big table
df_final = (
    df_users
    .join(df_subs,on='user_id',how='inner')
    .join(event_counts, on='user_id',how='left')
    .join(last_platform, on='user_id',how='left')
    .with_columns(pl.col('total_events').fill_null(0))
)

# %%
# Convert to Pandas for Scikit-Learn
df_pandas = df_final.to_pandas()

# %%
# Select only the columns we need for prediction
# We DROP 'user_id', 'email','name' because they dont predict churn
features = ['age','acquisition_channel','monthly_fee','total_events','platform']
target = 'churned'

X_raw = df_pandas[features]
y = df_pandas[target]

# %%
# One-Hot Encoding: Convert Text (Facebook, IOS) into numbers (0 or 1)
X = pd.get_dummies(X_raw, columns=['acquisition_channel','platform'], drop_first=True)

# %%
# Splitting Data (Train vs Test)
# I will hide  30% of data to test the model later
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
# Training the Model
print('Training Random Forest Model...')
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train,y_train)
# Out:
# Training Random Forest Model...
# RandomForestClassifier(random_state=42)

# %%
# Evaluate the Model
predictions = model.predict(X_test)
print('\n---Model Performance Report---')
print(classification_report(y_test,predictions))
# Out:
# ---Model Performance Report---
#               precision    recall  f1-score   support
#
#            0       0.47      0.45      0.46       137
#            1       0.53      0.55      0.54       154
#
#     accuracy                           0.50       291
#    macro avg       0.50      0.50      0.50       291
# weighted avg       0.50      0.50      0.50       291

# %%
# Feature Importance (The 'Why')
importances = pd.DataFrame({
    'Feature':X.columns,
    'Importance': model.feature_importances_
}).sort_values(by='Importance',ascending=True)

# %%
fig_model = px.bar(
    importances,
    x='Importance',
    y='Feature',
    orientation='h',
    title='What Drives User Churn? (Feature Importance)',
    color='Importance',
    color_continuous_scale='Viridis'
)

fig_model.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6fd158fb-3d12-4d3e-a118-bc96135ff815" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fd158fb-3d12-4d3e-a118-bc96135ff815")) {                    Plotly.newPlot(                        "6fd158fb-3d12-4d3e-a118-bc96135ff815",                        [{"alignmentgroup":"True","hovertemplate":"Importance=%{marker.color}\u003cbr\u003eFeature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0.02608812043516303,0.027292733762539875,0.03170309144876879,0.03274487610722297,0.03457820420126146,0.04022041908005772,0.2895571992386065,0.5178153557263796],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.02608812043516303,0.027292733762539875,0.03170309144876879,0.03274487610722297,0.03457820420126146,0.04022041908005772,0.2895571992386065,0.5178153557263796],"xaxis":"x","y":["acquisition_channel_Referral","acquisition_channel_Instagram","acquisition_channel_Organic","platform_Web","platform_iOS","monthly_fee","total_events","age"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter ...

# %% [markdown]
# # **Recommendation Engine**

# %%
bookings = df_events.filter(pl.col('event_name') == 'book_apt')

# %%
# Assigning a random doctor_id to each bookin to simulate a real database
random.seed(42)
doctor_ids = [f'Dr_{random.randint(1,20)}' for _ in range(bookings.height)]

display(doctor_ids)
# Out:
# ['Dr_4',
#  'Dr_1',
#  'Dr_9',
#  'Dr_8',
#  'Dr_8',
#  'Dr_5',
#  'Dr_4',
#  'Dr_18',
#  'Dr_3',
#  'Dr_19',
#  'Dr_14',
#  'Dr_2',
#  'Dr_1',
#  'Dr_3',
#  'Dr_7',
#  'Dr_8',
#  'Dr_17',
#  'Dr_20',
#  'Dr_1',
#  'Dr_18',
#  'Dr_7',
#  'Dr_18',
#  'Dr_14',
#  'Dr_8',
#  'Dr_15',
#  'Dr_19',
#  'Dr_9',
#  'Dr_1',
#  'Dr_6',
#  'Dr_14',
#  'Dr_11',
#  'Dr_9',
#  'Dr_5',
#  'Dr_7',
#  'Dr_11',
#  'Dr_4',
#  'Dr_3',
#  'Dr_13',
#  'Dr_10',
#  'Dr_6',
#  'Dr_15',
#  'Dr_18',
#  'Dr_10',
#  'Dr_20',
#  'Dr_17',
#  'Dr_1',
#  'Dr_18',
#  'Dr_10',
#  'Dr_4',
#  'Dr_5',
#  'Dr_9',
#  'Dr_4',
#  'Dr_4',
#  'Dr_18',
#  'Dr_5',
#  'Dr_9',
#  'Dr_10',
#  'Dr_20',
#  'Dr_7',
#  'Dr_11',
#  'Dr_7',
#  'Dr_9',
#  'Dr_17',
#  'Dr_16',
#  'Dr_9',
#  'Dr_2',
#  'Dr_3',
#  'Dr_14',
#  'Dr_9',
#  'Dr_2',
#  'Dr_1',
#  'Dr_11',
#  'Dr_5',
#  'Dr_9',
#  'Dr_6',
#  'Dr_15',
#  'Dr_18',
#  'Dr_14',
#  'Dr_18',
#  'Dr_1',
#  'Dr_4',
#  'Dr_3',
#  'Dr_5',
#  'Dr_18',
#  'Dr_2',
#  'Dr_12',
#  'Dr_19',
#  'Dr_18',
#  'Dr_5',
#  'Dr_14',
#  'Dr_5',
#  'Dr_2',
#  'Dr_10',
#  'Dr_12',
#  'Dr_2',
#  'Dr_12',
#  'Dr_7',
#  'Dr_8',
#  'Dr_4',
#  'Dr_12',
#  'Dr_18',
#  'Dr_14',
#  'Dr_20',
#  'Dr_5',
#  'Dr_8',
#  'Dr_6',
#  'Dr_6',
#  'Dr_14',
#  'Dr_1',
#  'Dr_6',
#  'Dr_11',
#  'Dr_14',
#  'Dr_8',
#  'Dr_9',
#  'Dr_6',
#  'Dr_4',
#  'Dr_13',
#  'Dr_2',
#  'Dr_16',
#  'Dr_8',
#  'Dr_7',
#  'Dr_15',
#  'Dr_12',
#  'Dr_10',
#  'Dr_8',
#  'Dr_8',
#  'Dr_1',
#  'Dr_7',
#  'Dr_13',
#  'Dr_11',
#  'Dr_9',
#  'Dr_3',
#  'Dr_9',
#  'Dr_12',
#  'Dr_17',
#  'Dr_13',
#  'Dr_18',
#  'Dr_11',
#  'Dr_1',
#  'Dr_4',
#  'Dr_9',
#  'Dr_6',
#  'Dr_19',
#  'Dr_9',
#  'Dr_2',
#  'Dr_4',
#  'Dr_20',
#  'Dr_14',
#  'Dr_12',
#  'Dr_11',
#  'Dr_14',
#  'Dr_20',
#  'Dr_17',
#  'Dr_4',
#  'Dr_13',
#  'Dr_19',
#  'Dr_7',
#  'Dr_9',
#  'Dr_2',
#  'Dr_14',
#  'Dr_1',
#  'Dr_17',
#  'Dr_18',
#  'Dr_7',
#  'Dr_12',
#  'Dr_14',
#  'Dr_3',
#  'Dr_11',
#  'Dr_20',
#  'Dr_11',
#  'Dr_4',
#  'Dr_10',
#  'Dr_17',
#  'Dr_10',
#  'Dr_14',
#  'Dr_11',
#  'Dr_13',
#  'Dr_10',
#  'Dr_18',
#  'Dr_5',
#  'Dr_7',
#  'Dr_14',
#  'Dr_13',
#  'Dr_6',
#  'Dr_20',
#  'Dr_19',
#  'Dr_11',
#  'Dr_11',
#  'Dr_13',
#  'Dr_9',
#  'Dr_14',
#  'Dr_9',
#  'Dr_3',
#  'Dr_16',
#  'Dr_1',
#  'Dr_18',
#  'Dr_2',
#  'Dr_12',
#  'Dr_8',
#  'Dr_3',
#  'Dr_2',
#  'Dr_1',
#  'Dr_8',
#  'Dr_7',
#  'Dr_1',
#  'Dr_20',
#  'Dr_5',
#  'Dr_8',
#  'Dr_5',
#  'Dr_16',
#  'Dr_4',
#  'Dr_19',
#  'Dr_7',
#  'Dr_15',
#  'Dr_9',
#  'Dr_12',
#  'Dr_6',
#  'Dr_20',
#  'Dr_20',
#  'Dr_4',
#  'Dr_6',
#  'Dr_10',
#  'Dr_4',
#  'Dr_19',
#  'Dr_1',
#  'Dr_10',
#  'Dr_19',
#  'Dr_13',
#  'Dr_13',
#  'Dr_7',
#  'Dr_3',
#  'Dr_19',
#  'Dr_8',
#  'Dr_4',
#  'Dr_10',
#  'Dr_20',
#  'Dr_4',
#  'Dr_19',
#  'Dr_2',
#  'Dr_12',
#  'Dr_18',
#  'Dr_14',
#  'Dr_12',
#  'Dr_3',
#  'Dr_17',
#  'Dr_11',
#  'Dr_1',
#  'Dr_14',
#  'Dr_16',
#  'Dr_4',
#  'Dr_14',
#  'Dr_12',
#  'Dr_15',
#  'Dr_5',
#  'Dr_14',
#  'Dr_6',
#  'Dr_17',
#  'Dr_9',
#  'Dr_20',
#  'Dr_18',
#  'Dr_16',
#  'Dr_15',
#  'Dr_14',
#  'Dr_19',
#  'Dr_9',
#  'Dr_11',
#  'Dr_8',
#  'Dr_3',
#  'Dr_9',
#  'Dr_15',
#  'Dr_8',
#  'Dr_15',
#  'Dr_19',
#  'Dr_20',
#  'Dr_13',
#  'Dr_11',
#  'Dr_1',
#  'Dr_16',
#  'Dr_11',
#  'Dr_6',
#  'Dr_16',
#  'Dr_7',
#  'Dr_12',
#  'Dr_9',
#  'Dr_11',
#  'Dr_9',
#  'Dr_20',
#  'Dr_9',
#  'Dr_18',
#  'Dr_1',
#  'Dr_17',
#  'Dr_7',
#  'Dr_3',
#  'Dr_8',
#  'Dr_14',
#  'Dr_16',
#  'Dr_18',
#  'Dr_8',
#  'Dr_16',
#  'Dr_16',
#  'Dr_15',
#  'Dr_1',
#  'Dr_3',
#  'Dr_10',
#  'Dr_8',
#  'Dr_13',
#  'Dr_8',
#  'Dr_10',
#  'Dr_19',
#  'Dr_12',
#  'Dr_16',
#  'Dr_18',
#  'Dr_17',
#  'Dr_12',
#  'Dr_14',
#  'Dr_18',
#  'Dr_11',
#  'Dr_12',
#  'Dr_15',
#  'Dr_9',
#  'Dr_10',
#  'Dr_9',
#  'Dr_8',
#  'Dr_4',
#  'Dr_7',
#  'Dr_11',
#  'Dr_4',
#  'Dr_18',
#  'Dr_6',
#  'Dr_7',
#  'Dr_7',
#  'Dr_16',
#  'Dr_9',
#  'Dr_19',
#  'Dr_17',
#  'Dr_20',
#  'Dr_10',
#  'Dr_4',
#  'Dr_7',
#  'Dr_10',
#  'Dr_8',
#  'Dr_12',
#  'Dr_6',
#  'Dr_10',
#  'Dr_1',
#  'Dr_18',
#  'Dr_5',
#  'Dr_9',
#  'Dr_2',
#  'Dr_2',
#  'Dr_18',
#  'Dr_10',
#  'Dr_5',
#  'Dr_16',
#  'Dr_4',
#  'Dr_1',
#  'Dr_19',
#  'Dr_10',
#  'Dr_16',
#  'Dr_16',
#  'Dr_15',
#  'Dr_11',
#  'Dr_6',
#  'Dr_2',
#  'Dr_9',
#  'Dr_16',
#  'Dr_4',
#  'Dr_3',
#  'Dr_13',
#  'Dr_16',
#  'Dr_3',
#  'Dr_19',
#  'Dr_2',
#  'Dr_5',
#  'Dr_5',
#  'Dr_19',
#  'Dr_10',
#  'Dr_3',
#  'Dr_8',
#  'Dr_4',
#  'Dr_18',
#  'Dr_14',
#  'Dr_20',
#  'Dr_20',
#  'Dr_20',
#  'Dr_8',
#  'Dr_17',
#  'Dr_13',
#  'Dr_15',
#  'Dr_15',
#  'Dr_10',
#  'Dr_19',
#  'Dr_14',
#  'Dr_10',
#  'Dr_19',
#  'Dr_20',
#  'Dr_2',
#  'Dr_20',
#  'Dr_4',
#  'Dr_7',
#  'Dr_7',
#  'Dr_9',
#  'Dr_3',
#  'Dr_6',
#  'Dr_8',
#  'Dr_6',
#  'Dr_18',
#  'Dr_3',
#  'Dr_6',
#  'Dr_1',
#  'Dr_14',
#  'Dr_15',
#  'Dr_20',
#  'Dr_16',
#  'Dr_10',
#  'Dr_2',
#  'Dr_8',
#  'Dr_10',
#  'Dr_10',
#  'Dr_15',
#  'Dr_3',
#  'Dr_8',
#  'Dr_9',
#  'Dr_19',
#  'Dr_7',
#  'Dr_14',
#  'Dr_4',
#  'Dr_18',
#  'Dr_8',
#  'Dr_5',
#  'Dr_9',
#  'Dr_5',
#  'Dr_3',
#  'Dr_2',
#  'Dr_6',
#  'Dr_10',
#  'Dr_20',
#  'Dr_19',
#  'Dr_10',
#  'Dr_15',
#  'Dr_4',
#  'Dr_15',
#  'Dr_10',
#  'Dr_13',
#  'Dr_9',
#  'Dr_17',
#  'Dr_18',
#  'Dr_16',
#  'Dr_15',
#  'Dr_3',
#  'Dr_20',
#  'Dr_2',
#  'Dr_14',
#  'Dr_11',
#  'Dr_20',
#  'Dr_9',
#  'Dr_1',
#  'Dr_3',
#  'Dr_8',
#  'Dr_19',
#  'Dr_19',
#  'Dr_1',
#  'Dr_9',
#  'Dr_19',
#  'Dr_2',
#  'Dr_6',
#  'Dr_16',
#  'Dr_17',
#  'Dr_15',
#  'Dr_9',
#  'Dr_6',
#  'Dr_19',
#  'Dr_14',
#  'Dr_16',
#  'Dr_3',
#  'Dr_16',
#  'Dr_12',
#  'Dr_14',
#  'Dr_11',
#  'Dr_11',
#  'Dr_4',
#  'Dr_6',
#  'Dr_11',
#  'Dr_14',
#  'Dr_16',
#  'Dr_10',
#  'Dr_13',
#  'Dr_18',
#  'Dr_2',
#  'Dr_15',
#  'Dr_3',
#  'Dr_11',
#  'Dr_9',
#  'Dr_11',
#  'Dr_4',
#  'Dr_13',
#  'Dr_17',
#  'Dr_1',
#  'Dr_18',
#  'Dr_15',
#  'Dr_14',
#  'Dr_2',
#  'Dr_7',
#  'Dr_17',
#  'Dr_12',
#  'Dr_20',
#  'Dr_16',
#  'Dr_15',
#  'Dr_2',
#  'Dr_7',
#  'Dr_9',
#  'Dr_18',
#  'Dr_5',
#  'Dr_10',
#  'Dr_15',
#  'Dr_16',
#  'Dr_4',
#  'Dr_1',
#  'Dr_20',
#  'Dr_8',
#  'Dr_6',
#  'Dr_10',
#  'Dr_18',
#  'Dr_1',
#  'Dr_18',
#  'Dr_14',
#  'Dr_3',
#  'Dr_8',
#  'Dr_4',
#  'Dr_15',
#  'Dr_4',
#  'Dr_5',
#  'Dr_16',
#  'Dr_10',
#  'Dr_17',
#  'Dr_9',
#  'Dr_14',
#  'Dr_16',
#  'Dr_16',
#  'Dr_8',
#  'Dr_15',
#  'Dr_18',
#  'Dr_5',
#  'Dr_13',
#  'Dr_7',
#  'Dr_20',
#  'Dr_17',
#  'Dr_5',
#  'Dr_3',
#  'Dr_9',
#  'Dr_14',
#  'Dr_11',
#  'Dr_17',
#  'Dr_9',
#  'Dr_1',
#  ...]

# %%
# Adding these doctor IDs to our booking data
bookings = bookings.with_columns(pl.Series(name='doctor_id', values=doctor_ids))

display(bookings.head())
# Out:
# shape: (5, 6)
# ┌──────────────────────┬─────────────────────┬────────────┬─────────────────┬──────────┬───────────┐
# │ event_id             ┆ user_id             ┆ event_name ┆ event_timestamp ┆ platform ┆ doctor_id │
# │ ---                  ┆ ---                 ┆ ---        ┆ ---             ┆ ---      ┆ ---       │
# │ str                  ┆ str                 ┆ str        ┆ str             ┆ str      ┆ str       │
# ╞══════════════════════╪═════════════════════╪════════════╪═════════════════╪══════════╪═══════════╡
# │ 9f130820-0f3b-45f9-9 ┆ 8aa9d39a-726f-46fd- ┆ book_apt   ┆ 2025-05-22      ┆ Android  ┆ Dr_4      │
# │ 345-c526a4…          ┆ 8ec9-8bf100…        ┆            ┆                 ┆          ┆           │
# │ 19664504-6e7e-4978-8 ┆ b4adaf89-0ff1-4a9f- ┆ book_apt   ┆ 2025-08-05      ┆ Android  ┆ Dr_1      │
# │ 69d-7b0161…          ┆ ba37-0623bc…        ┆            ┆                 ┆          ┆           │
# │ fbb64c04-0dc5-4a75-a ┆ 20bd1422-0b0b-41de- ┆ book_apt   ┆ 2025-11-20      ┆ iOS      ┆ Dr_9      │
# │ 835-3c7e3e…          ┆ be61-2d6605…        ┆            ┆                 ┆          ┆           │
# │ 2b0d5b1c-027d-4e84-9 ┆ 69b6175e-76c5-4d2b- ┆ book_apt   ┆ 2024-12-21      ┆ Android  ┆ Dr_8      │
# │ b0e-09ffb6…          ┆ a9fd-d358cb…        ┆            ┆                 ┆          ┆           │
# │ 6cddab56-8c30-4073-a ┆ 5fb698a5-e920-4b3a- ┆ book_apt   ┆ 2025-05-21      ┆ Android  ┆ Dr_8      │
# │ 8e4-c8dedd…          ┆ a951-c8a7cd…        ┆            ┆                 ┆          ┆           │
# └──────────────────────┴─────────────────────┴────────────┴─────────────────┴──────────┴───────────┘

# %%
# Creating The Matrix: Count now many times User U booked Doctor D
# Convert to Pandas for the pivot table (easier for matrices)
df_bookings = bookings.to_pandas()

# %%
user_item_matrix = df_bookings.pivot_table(
    index='user_id',
    columns='doctor_id',
    aggfunc='size',
    fill_value=0
)

print('User-Item Matrix Created:')
print(user_item_matrix.head())
# Out:
# User-Item Matrix Created:
# doctor_id                             Dr_1  Dr_10  Dr_11  Dr_12  Dr_13  Dr_14  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a     0      0      0      0      0      0
# 0123a348-638a-4df6-adf7-2cd3979aa051     0      0      0      1      0      0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0     0      0      0      0      0      1
# 01a0960b-ba89-434b-b224-7627c1e0248e     0      1      0      1      0      0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004     0      0      0      0      0      0
#
# doctor_id                             Dr_15  Dr_16  Dr_17  Dr_18  Dr_19  Dr_2  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a      0      0      0      0      0     0
# 0123a348-638a-4df6-adf7-2cd3979aa051      0      0      1      0      0     0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0      0      0      0      0      0     0
# 01a0960b-ba89-434b-b224-7627c1e0248e      0      0      0      0      0     0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004      1      0      0      0      1     0
#
# doctor_id                             Dr_20  Dr_3  Dr_4  Dr_5  Dr_6  Dr_7  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a      1     1     0     0     0     0
# 0123a348-638a-4df6-adf7-2cd3979aa051      0     0     0     0     0     0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0      0     0     0     0     0     0
# 01a0960b-ba89-434b-b224-7627c1e0248e      1     0     0     0     0     0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004      0     0     0     0     0     0
#
# doctor_id                             Dr_8  Dr_9
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a     0     0
# 0123a348-638a-4df6-adf7-2cd3979aa051     0     0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0     0     0
# 01a0960b-ba89-434b-b224-7627c1e0248e     0     0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004     0     0

# %%
# Calculate Similarity (The Math)
# We calculate the Cosine Similarity between USERS
# How similar is User A's booking history to User B's ?

user_similarity = cosine_similarity(user_item_matrix)
user_similarity_df = pd.DataFrame(
    user_similarity,
    index=user_item_matrix.index,
    columns=user_item_matrix.index
)

display(user_similarity_df.head())
# Out:
# user_id                               006ed6e3-6fa1-4735-b572-f3d00b5cea6a  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                              1.000000
# 0123a348-638a-4df6-adf7-2cd3979aa051                              0.000000
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                              0.000000
# 01a0960b-ba89-434b-b224-7627c1e0248e                              0.408248
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                              0.000000
#
# user_id                               0123a348-638a-4df6-adf7-2cd3979aa051  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                              0.000000
# 0123a348-638a-4df6-adf7-2cd3979aa051                              1.000000
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                              0.000000
# 01a0960b-ba89-434b-b224-7627c1e0248e                              0.408248
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                              0.000000
#
# user_id                               013ca998-2b2b-458c-ada5-8dadf56aabc0  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                                   0.0
# 0123a348-638a-4df6-adf7-2cd3979aa051                                   0.0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                                   1.0
# 01a0960b-ba89-434b-b224-7627c1e0248e                                   0.0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                                   0.0
#
# user_id                               01a0960b-ba89-434b-b224-7627c1e0248e  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                              0.408248
# 0123a348-638a-4df6-adf7-2cd3979aa051                              0.408248
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                              0.000000
# 01a0960b-ba89-434b-b224-7627c1e0248e                              1.000000
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                              0.000000
#
# user_id                               020e2e6a-bcc8-409b-98da-ae8cf9f7e004  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                                   0.0
# 0123a348-638a-4df6-adf7-2cd3979aa051                                   0.0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                                   0.0
# 01a0960b-ba89-434b-b224-7627c1e0248e                                   0.0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                                   1.0
#
# user_id                               02223c10-f82f-4dc3-9c35-730b49d52453  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                                   0.0
# 0123a348-638a-4df6-adf7-2cd3979aa051                                   0.0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                                   0.0
# 01a0960b-ba89-434b-b224-7627c1e0248e                                   0.0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                                   0.0
#
# user_id                               0262bf90-3bd8-4e22-8b0f-ab8e9fa4ce21  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                                   0.0
# 0123a348-638a-4df6-adf7-2cd3979aa051                                   0.0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                                   0.0
# 01a0960b-ba89-434b-b224-7627c1e0248e                                   0.0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                                   0.0
#
# user_id                               02ff9754-5291-4b6d-a592-4c9f29714f1f  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                                   0.0
# 0123a348-638a-4df6-adf7-2cd3979aa051                                   0.0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                                   0.0
# 01a0960b-ba89-434b-b224-7627c1e0248e                                   0.0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                                   0.0
#
# user_id                               030b23db-bfbe-4ca3-b610-350b76f53b65  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                              0.408248
# 0123a348-638a-4df6-adf7-2cd3979aa051                              0.000000
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                              0.000000
# 01a0960b-ba89-434b-b224-7627c1e0248e                              0.333333
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                              0.000000
#
# user_id                               03e7dd21-1d4d-46d6-860d-113d2851a8be  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                               0.00000
# 0123a348-638a-4df6-adf7-2cd3979aa051                               0.00000
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                               0.00000
# 01a0960b-ba89-434b-b224-7627c1e0248e                               0.57735
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                               0.00000
#
# user_id                               ...  \
# user_id                               ...
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a  ...
# 0123a348-638a-4df6-adf7-2cd3979aa051  ...
# 013ca998-2b2b-458c-ada5-8dadf56aabc0  ...
# 01a0960b-ba89-434b-b224-7627c1e0248e  ...
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004  ...
#
# user_id                               fd595978-7965-42e3-b9b0-94ac4d2d8efd  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                                   0.0
# 0123a348-638a-4df6-adf7-2cd3979aa051                                   0.0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                                   0.0
# 01a0960b-ba89-434b-b224-7627c1e0248e                                   0.0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                                   0.0
#
# user_id                               fd5cd74e-8778-4be6-9b29-f76ec8880b2c  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                                   0.0
# 0123a348-638a-4df6-adf7-2cd3979aa051                                   0.0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                                   0.0
# 01a0960b-ba89-434b-b224-7627c1e0248e                                   0.0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                                   0.5
#
# user_id                               fd888cbd-a804-4463-8d36-f5e492a6f3e6  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                               0.00000
# 0123a348-638a-4df6-adf7-2cd3979aa051                               0.00000
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                               0.00000
# 01a0960b-ba89-434b-b224-7627c1e0248e                               0.57735
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                               0.00000
#
# user_id                               fde6849b-468b-42af-9ca4-364d5d9ad9f1  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                                   0.0
# 0123a348-638a-4df6-adf7-2cd3979aa051                                   0.0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                                   0.0
# 01a0960b-ba89-434b-b224-7627c1e0248e                                   0.0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                                   0.0
#
# user_id                               fec88839-ec35-43de-b414-e3e1a3871e92  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                                   0.0
# 0123a348-638a-4df6-adf7-2cd3979aa051                                   0.0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                                   0.0
# 01a0960b-ba89-434b-b224-7627c1e0248e                                   0.0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                                   0.0
#
# user_id                               fed024cb-b6f3-4bd4-8409-b7c8ef59a4b5  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                                   0.0
# 0123a348-638a-4df6-adf7-2cd3979aa051                                   0.0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                                   0.0
# 01a0960b-ba89-434b-b224-7627c1e0248e                                   0.0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                                   0.5
#
# user_id                               fef72410-5528-4c45-a37a-a99961ff1d9a  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                               0.00000
# 0123a348-638a-4df6-adf7-2cd3979aa051                               0.00000
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                               0.00000
# 01a0960b-ba89-434b-b224-7627c1e0248e                               0.57735
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                               0.00000
#
# user_id                               ff12fe28-b840-4136-867e-4b72316e8645  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                                   0.0
# 0123a348-638a-4df6-adf7-2cd3979aa051                                   0.0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                                   0.0
# 01a0960b-ba89-434b-b224-7627c1e0248e                                   0.0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                                   0.0
#
# user_id                               ff5376a4-bb48-4bba-ac73-5be00ceeddc2  \
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                                   0.0
# 0123a348-638a-4df6-adf7-2cd3979aa051                                   0.0
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                                   0.0
# 01a0960b-ba89-434b-b224-7627c1e0248e                                   0.0
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                                   0.0
#
# user_id                               ffc9ff30-9f9a-4a33-9ad6-ff7be4af65aa
# user_id
# 006ed6e3-6fa1-4735-b572-f3d00b5cea6a                              0.000000
# 0123a348-638a-4df6-adf7-2cd3979aa051                              0.632456
# 013ca998-2b2b-458c-ada5-8dadf56aabc0                              0.000000
# 01a0960b-ba89-434b-b224-7627c1e0248e                              0.774597
# 020e2e6a-bcc8-409b-98da-ae8cf9f7e004                              0.000000
#
# [5 rows x 718 columns]

# %% [markdown]
# # **The Recommendation Function**

# %%
def recommend_doctors(target_user_id, n_recommendations=3):
  if target_user_id not in user_item_matrix.index:
    return 'User has no booking history (Cold Start)'

  sim_scores = user_similarity_df[target_user_id]
  similar_users = sim_scores.sort_values(ascending=False).index[1:4]

  recommended_docs = {}

  for peer in similar_users:
    # What did the peer book?
    peer_books = user_item_matrix.loc[peer]

    # Filter for doctors the peer booked (>0)
    docs = peer_books[peer_books > 0].index.tolist()

    for doc in docs:
      # Only recommend if our targetr user HAS NOT book this doctor yet
      if user_item_matrix.loc[target_user_id, doc] == 0:
          recommended_docs[doc] = recommended_docs.get(doc,0) + 1

  sorted_recs = sorted(recommended_docs.items(), key=lambda x:x[1], reverse=True)
  return [doc[0] for doc in sorted_recs[:n_recommendations]]

# %%
# Testing the Engine
# Picking a random user from our matrix

test_user = user_item_matrix.index[0]
recs = recommend_doctors(test_user)

# %%
print(f'\n--- Recommendations for User {test_user[:8]}... ---')
print(f'Based on similar users, they should book: {recs}')
# Out:
# --- Recommendations for User 006ed6e3... ---
# Based on similar users, they should book: []
